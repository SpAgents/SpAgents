# %% [markdown]
# # gpt 4o

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY", ""),
    base_url=os.getenv("OPENAI_BASE_URL", "https://api.example.com/v1/chat/completions"),
)

response = client.chat.completions.create(
    model="gpt-4o-2024-08-06",  # 指定 GPT-4o 模型
    messages=[
        # {"role": "system", "content": "你是一个乐于助人的AI助手。"},
        {"role": "user", "content": "什么是axSpA？"},
    ],
    temperature=0.7,
)

# %%
import os
from openai import OpenAI

# 初始化客户端，设置自定义的 base_url
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY", ""),
    base_url=os.getenv("OPENAI_BASE_URL", "https://api.example.com/v1"),
)

# 调用 GPT-4o 模型
response = client.chat.completions.create(
    model="gpt-4o-2024-08-06",
    messages=[
        {"role": "system", "content": "你是一个乐于助人的助手。"},
        {"role": "user", "content": "什么是axSpA？"},
    ],
    temperature=0.7,
    max_tokens=200,
)

# %%
print(response)
